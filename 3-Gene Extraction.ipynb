# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### GSE57957

# %%
gpl_df = pd.read_table('GPL10558-50081.txt', skiprows=30)
deg_df = pd.read_table('topconfects - GSE57957.txt', names=['ID'])

# %%
gpl_df.head(25)
# Out:
#               ID       Species  Source   Search_Key  Transcript ILMN_Gene  \
# 0   ILMN_1343048           NaN     NaN          NaN         NaN       NaN
# 1   ILMN_1343049           NaN     NaN          NaN         NaN       NaN
# 2   ILMN_1343050           NaN     NaN          NaN         NaN       NaN
# 3   ILMN_1343052           NaN     NaN          NaN         NaN       NaN
# 4   ILMN_1343059           NaN     NaN          NaN         NaN       NaN
# 5   ILMN_1343061           NaN     NaN          NaN         NaN       NaN
# 6   ILMN_1343062           NaN     NaN          NaN         NaN       NaN
# 7   ILMN_1343063           NaN     NaN          NaN         NaN       NaN
# 8   ILMN_1343064           NaN     NaN          NaN         NaN       NaN
# 9   ILMN_1343291  Homo sapiens  RefSeq  NM_001402.4   ILMN_5311    EEF1A1
# 10  ILMN_1343295  Homo sapiens  RefSeq          NaN  ILMN_27206     GAPDH
# 11  ILMN_1343296           NaN     NaN          NaN         NaN       NaN
# ...

# %%
gpl_df.tail(25)
# Out:
#                  ID       Species  Source      Search_Key   Transcript  \
# 48082  ILMN_3311070  Homo sapiens  RefSeq     NR_030361.1  ILMN_388131
# 48083  ILMN_3311075  Homo sapiens  RefSeq     NR_031736.1  ILMN_388655
# 48084  ILMN_3311080  Homo sapiens  RefSeq     NR_030165.1  ILMN_387798
# 48085  ILMN_3311085  Homo sapiens  RefSeq     NR_003194.1  ILMN_165933
# 48086  ILMN_3311090  Homo sapiens  RefSeq     NR_030294.1  ILMN_388015
# 48087  ILMN_3311095  Homo sapiens  RefSeq     NR_030373.1  ILMN_388175
# 48088  ILMN_3311100  Homo sapiens  RefSeq     NR_029476.1  ILMN_387943
# 48089  ILMN_3311105  Homo sapiens  RefSeq     NR_003206.1  ILMN_162444
# 48090  ILMN_3311110  Homo sapiens  RefSeq     NR_029899.1  ILMN_387777
# 48091  ILMN_3311115  Homo sapiens  RefSeq     NR_031608.1  ILMN_388711
# 48092  ILMN_3311120  Homo sapiens  RefSeq     NR_031686.1  ILMN_388736
# 48093  ILMN_3311125  Homo sapiens  RefSeq     NR_031565.1  ILMN_388705
# ...

# %%
gpl_df.columns
# Out:
# Index(['ID', 'Species', 'Source', 'Search_Key', 'Transcript', 'ILMN_Gene',
#        'Source_Reference_ID', 'RefSeq_ID', 'Unigene_ID', 'Entrez_Gene_ID',
#        'GI', 'Accession', 'Symbol', 'Protein_Product', 'Probe_Id',
#        'Array_Address_Id', 'Probe_Type', 'Probe_Start', 'SEQUENCE',
#        'Chromosome', 'Probe_Chr_Orientation', 'Probe_Coordinates', 'Cytoband',
#        'Definition', 'Ontology_Component', 'Ontology_Process',
#        'Ontology_Function', 'Synonyms', 'Obsolete_Probe_Id', 'GB_ACC'],
#       dtype='object')

# %%
deg_df.head()
# Out:
#              ID
# 0  ILMN_1797519
# 1  ILMN_2051972
# 2  ILMN_1782754
# 3  ILMN_1672148
# 4  ILMN_2278335

# %%
deg_df.tail()
# Out:
#                  ID
# 47318  ILMN_1728858
# 47319  ILMN_1782845
# 47320  ILMN_1714882
# 47321  ILMN_1713321
# 47322  ILMN_1659290

# %%
deg_df.shape
# Out:
# (47323, 1)

# %%
merged_df = pd.merge(deg_df, gpl_df, on='ID')

# %%
merged_df.dropna(subset=['ILMN_Gene'], inplace=True)

# %%
merged_df.shape
# Out:
# (47323, 30)

# %%
gene_list = merged_df['ILMN_Gene'].to_list()

# %%
merged_df['ILMN_Gene'].to_csv('gse57957.csv', index=False)

# %% [markdown]
# ### GSE62232

# %%
gpl_df = pd.read_table('GPL570-55999.txt', skiprows=16)
deg_df = pd.read_table('topconfects - GSE62232.txt', names=['ID'])
# Out:
# <ipython-input-12-b8f412f83b2f>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   gpl_df = pd.read_table('GPL570-55999.txt', skiprows=16)

# %%
gpl_df.head(25)
# Out:
#               ID     GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0      1007_s_at     U48705     NaN            Homo sapiens     Oct 6, 2014
# 1        1053_at     M87338     NaN            Homo sapiens     Oct 6, 2014
# 2         117_at     X51757     NaN            Homo sapiens     Oct 6, 2014
# 3         121_at     X69699     NaN            Homo sapiens     Oct 6, 2014
# 4      1255_g_at     L36861     NaN            Homo sapiens     Oct 6, 2014
# 5        1294_at     L13852     NaN            Homo sapiens     Oct 6, 2014
# 6        1316_at     X55005     NaN            Homo sapiens     Oct 6, 2014
# 7        1320_at     X79510     NaN            Homo sapiens     Oct 6, 2014
# 8      1405_i_at     M21121     NaN            Homo sapiens     Oct 6, 2014
# 9        1431_at     J02843     NaN            Homo sapiens     Oct 6, 2014
# 10       1438_at     X75208     NaN            Homo sapiens     Oct 6, 2014
# ...

# %%
gpl_df.tail(25)
# Out:
#                           ID GB_ACC    SPOT_ID Species Scientific Name  \
# 54650    AFFX-r2-Bs-dap-M_at    NaN  --Control            Homo sapiens
# 54651    AFFX-r2-Bs-lys-3_at    NaN  --Control            Homo sapiens
# 54652    AFFX-r2-Bs-lys-5_at    NaN  --Control            Homo sapiens
# 54653    AFFX-r2-Bs-lys-M_at    NaN  --Control            Homo sapiens
# 54654    AFFX-r2-Bs-phe-3_at    NaN  --Control            Homo sapiens
# 54655    AFFX-r2-Bs-phe-5_at    NaN  --Control            Homo sapiens
# 54656    AFFX-r2-Bs-phe-M_at    NaN  --Control            Homo sapiens
# 54657  AFFX-r2-Bs-thr-3_s_at    NaN  --Control            Homo sapiens
# 54658  AFFX-r2-Bs-thr-5_s_at    NaN  --Control            Homo sapiens
# 54659  AFFX-r2-Bs-thr-M_s_at    NaN  --Control            Homo sapiens
# 54660   AFFX-r2-Ec-bioB-3_at    NaN  --Control            Homo sapiens
# 54661   AFFX-r2-Ec-bioB-5_at    NaN  --Control            Homo sapiens
# ...

# %%
gpl_df.columns
# Out:
# Index(['ID', 'GB_ACC', 'SPOT_ID', 'Species Scientific Name', 'Annotation Date',
#        'Sequence Type', 'Sequence Source', 'Target Description',
#        'Representative Public ID', 'Gene Title', 'Gene Symbol',
#        'ENTREZ_GENE_ID', 'RefSeq Transcript ID',
#        'Gene Ontology Biological Process', 'Gene Ontology Cellular Component',
#        'Gene Ontology Molecular Function'],
#       dtype='object')

# %%
deg_df.head()
# Out:
#              ID
# 0     1255_g_at
# 1    1552266_at
# 2    1552269_at
# 3    1552296_at
# 4  1552320_a_at

# %%
deg_df.tail()
# Out:
#                    ID
# 9536   AFFX-ThrX-5_at
# 9537   AFFX-ThrX-M_at
# 9538  AFFX-TrpnX-3_at
# 9539  AFFX-TrpnX-5_at
# 9540  AFFX-TrpnX-M_at

# %%
deg_df.shape
# Out:
# (9541, 1)

# %%
merged_df_2 = pd.merge(deg_df, gpl_df, on='ID')

# %%
merged_df_2.dropna(subset=['Gene Symbol'], inplace=True)

# %%
merged_df_2.shape
# Out:
# (6529, 16)

# %%
gene_list = merged_df_2['Gene Symbol'].to_list()

# %%
merged_df_2['Gene Symbol'].to_csv('gse62232.csv', index=False)

# %% [markdown]
# ### GSE112790

# %%
gpl_df = pd.read_table('GPL570-55999.txt', skiprows=16)
deg_df = pd.read_table('topconfects - GSE112790.txt', names=['ID'])
# Out:
# <ipython-input-24-79f15b129fbd>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   gpl_df = pd.read_table('GPL570-55999.txt', skiprows=16)

# %%
gpl_df.head(25)
# Out:
#               ID     GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0      1007_s_at     U48705     NaN            Homo sapiens     Oct 6, 2014
# 1        1053_at     M87338     NaN            Homo sapiens     Oct 6, 2014
# 2         117_at     X51757     NaN            Homo sapiens     Oct 6, 2014
# 3         121_at     X69699     NaN            Homo sapiens     Oct 6, 2014
# 4      1255_g_at     L36861     NaN            Homo sapiens     Oct 6, 2014
# 5        1294_at     L13852     NaN            Homo sapiens     Oct 6, 2014
# 6        1316_at     X55005     NaN            Homo sapiens     Oct 6, 2014
# 7        1320_at     X79510     NaN            Homo sapiens     Oct 6, 2014
# 8      1405_i_at     M21121     NaN            Homo sapiens     Oct 6, 2014
# 9        1431_at     J02843     NaN            Homo sapiens     Oct 6, 2014
# 10       1438_at     X75208     NaN            Homo sapiens     Oct 6, 2014
# ...

# %%
gpl_df.tail(25)
# Out:
#                           ID GB_ACC    SPOT_ID Species Scientific Name  \
# 54650    AFFX-r2-Bs-dap-M_at    NaN  --Control            Homo sapiens
# 54651    AFFX-r2-Bs-lys-3_at    NaN  --Control            Homo sapiens
# 54652    AFFX-r2-Bs-lys-5_at    NaN  --Control            Homo sapiens
# 54653    AFFX-r2-Bs-lys-M_at    NaN  --Control            Homo sapiens
# 54654    AFFX-r2-Bs-phe-3_at    NaN  --Control            Homo sapiens
# 54655    AFFX-r2-Bs-phe-5_at    NaN  --Control            Homo sapiens
# 54656    AFFX-r2-Bs-phe-M_at    NaN  --Control            Homo sapiens
# 54657  AFFX-r2-Bs-thr-3_s_at    NaN  --Control            Homo sapiens
# 54658  AFFX-r2-Bs-thr-5_s_at    NaN  --Control            Homo sapiens
# 54659  AFFX-r2-Bs-thr-M_s_at    NaN  --Control            Homo sapiens
# 54660   AFFX-r2-Ec-bioB-3_at    NaN  --Control            Homo sapiens
# 54661   AFFX-r2-Ec-bioB-5_at    NaN  --Control            Homo sapiens
# ...

# %%
gpl_df.columns
# Out:
# Index(['ID', 'GB_ACC', 'SPOT_ID', 'Species Scientific Name', 'Annotation Date',
#        'Sequence Type', 'Sequence Source', 'Target Description',
#        'Representative Public ID', 'Gene Title', 'Gene Symbol',
#        'ENTREZ_GENE_ID', 'RefSeq Transcript ID',
#        'Gene Ontology Biological Process', 'Gene Ontology Cellular Component',
#        'Gene Ontology Molecular Function'],
#       dtype='object')

# %%
deg_df.head()
# Out:
#              ID
# 0     1255_g_at
# 1    1552266_at
# 2    1552269_at
# 3  1552320_a_at
# 4  1552321_a_at

# %%
deg_df.tail()
# Out:
#             ID
# 7407  34471_at
# 7408  37566_at
# 7409  51226_at
# 7410  65438_at
# 7411  91580_at

# %%
deg_df.shape
# Out:
# (7412, 1)

# %%
merged_df_3 = pd.merge(deg_df, gpl_df, on='ID')

# %%
merged_df_3.dropna(subset=['Gene Symbol'], inplace=True)

# %%
merged_df_3.shape
# Out:
# (4933, 16)

# %%
gene_list = merged_df_3['Gene Symbol'].to_list()

# %%
merged_df_3['Gene Symbol'].to_csv('gse112790.csv', index=False)

# %% [markdown]
# ###TCGA

# %%
tcga = pd.read_table('degs.txt', sep=' ')

# %%
tcga.head()
# Out:
#                     logFC    logCPM         LR        PValue           FDR  \
# ENSG00000002079  1.995614 -0.386883  23.593691  1.189770e-06  8.161343e-06
# ENSG00000002726 -2.145351  2.848888  26.285641  2.944699e-07  2.286535e-06
# ENSG00000003249  1.516839  5.866112  39.119183  3.987073e-10  4.978835e-09
# ENSG00000003987  1.658222  4.886749  29.221421  6.456148e-08  5.669198e-07
# ENSG00000004838  1.801835  0.708423  41.608225  1.115231e-10  1.517960e-09
#
#                 gene_name                       gene_type
# ENSG00000002079     MYH16  transcribed_unitary_pseudogene
# ENSG00000002726      AOC1                  protein_coding
# ENSG00000003249    DBNDD1                  protein_coding
# ENSG00000003987     MTMR7                  protein_coding
# ENSG00000004838   ZMYND10                  protein_coding

# %%
tcga.columns
# Out:
# Index(['logFC', 'logCPM', 'LR', 'PValue', 'FDR', 'gene_name', 'gene_type'], dtype='object')

# %%
genes = tcga['gene_name'].reset_index(drop=True)

# %%
genes.shape
# Out:
# (4412,)

# %%
genes.to_csv('tcga_degs_extracted.csv', index=False)
